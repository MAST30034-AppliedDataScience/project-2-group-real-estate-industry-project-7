# %% [markdown]
# ### Import Library

# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
# read yearly income csv
yearly_income = pd.read_csv('../data/curated/pop_income_postcode.csv', index_col=0)

# Keep only the specified columns
yearly_income = yearly_income[['SA2', 'SA2 name', '2016-17', '2017-18', '2018-19', '2019-20', '2020-21', 'average_income', 'income_growth_rate', 'affluence_index', 'postcode']]

# %%
yearly_income
# Out:
#            SA2             SA2 name  2016-17  2017-18  2018-19  2019-20  \
# 0    201011001            Alfredton  50596.0  52448.0  53932.0  55204.0
# 1    201011002             Ballarat  50093.0  51736.0  53688.0  53784.0
# 2    201011005            Buninyong  48877.0  51034.0  52377.0  54308.0
# 3    201011006            Delacombe  46176.0  47759.0  49909.0  51915.0
# 4    201011006            Delacombe  46176.0  47759.0  49909.0  51915.0
# ..         ...                  ...      ...      ...      ...      ...
# 984  217041478         Moyne - West  41889.0  43136.0  45256.0  46843.0
# 985  217041478         Moyne - West  41889.0  43136.0  45256.0  46843.0
# 986  217041478         Moyne - West  41889.0  43136.0  45256.0  46843.0
# 987  217041479  Warrnambool - North  44509.0  46945.0  48855.0  50654.0
# 988  217041480  Warrnambool - South  43149.0  45726.0  47242.0  49080.0
#
#      2020-21  average_income  income_growth_rate  affluence_index  postcode
# 0    58036.0         54043.2            0.147047     37830.284114    3350.0
# 1    55998.0         53059.8            0.117881     37141.895364    3354.0
# 2    56408.0         52600.8            0.154081     36820.606224    3357.0
# 3    52792.0         49710.2            0.143278     34797.182983    3352.0
# 4    52792.0         49710.2            0.143278     34797.182983    3358.0
# ..       ...             ...                 ...              ...       ...
# 984  50360.0         45496.8            0.202225     31847.820667    3287.0
# 985  50360.0         45496.8            0.202225     31847.820667    3286.0
# 986  50360.0         45496.8            0.202225     31847.820667    3289.0
# 987  52518.0         48696.2            0.179941     34087.393982    3280.0
# 988  52359.0         47511.2            0.213446     33257.904034    3277.0
#
# [989 rows x 11 columns]

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
# Extract only income columns for prediction
income_columns = ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21']
suburbs = yearly_income[['SA2']]  # Keeping track of suburb names

# Function to fit ARIMA model and predict future 3 years income
def predict_future_income(income_series, forecast_years=3):
    # Handle NaN by filling with the median 
    income_series = income_series.fillna(income_series.median())

    # Fit ARIMA model
    model = ARIMA(income_series, order=(2, 1, 2))
    model_fit = model.fit()

    # Forecast the next 3 years
    forecast = model_fit.forecast(steps=forecast_years)
    
    return list(forecast)

# Predicting future income for each suburb and storing the results
for idx, row in yearly_income.iterrows():

    past_income = row[income_columns].astype(float)  # Convert income data to float for ARIMA model
    # Get future income predictions
    future_income = predict_future_income(past_income, forecast_years=3)
    # Adding predicted future income to the dataset
    yearly_income.at[idx, '2021-22(pred)'] =  future_income[0]
    yearly_income.at[idx, '2022-23(pred)'] =  future_income[1]
    yearly_income.at[idx, '2023-24(pred)'] =  future_income[2]

# %%
yearly_income = yearly_income.dropna(axis='rows')
yearly_income
# Out:
#            SA2             SA2 name  2016-17  2017-18  2018-19  2019-20  \
# 0    201011001            Alfredton  50596.0  52448.0  53932.0  55204.0
# 1    201011002             Ballarat  50093.0  51736.0  53688.0  53784.0
# 2    201011005            Buninyong  48877.0  51034.0  52377.0  54308.0
# 3    201011006            Delacombe  46176.0  47759.0  49909.0  51915.0
# 4    201011006            Delacombe  46176.0  47759.0  49909.0  51915.0
# ..         ...                  ...      ...      ...      ...      ...
# 984  217041478         Moyne - West  41889.0  43136.0  45256.0  46843.0
# 985  217041478         Moyne - West  41889.0  43136.0  45256.0  46843.0
# 986  217041478         Moyne - West  41889.0  43136.0  45256.0  46843.0
# 987  217041479  Warrnambool - North  44509.0  46945.0  48855.0  50654.0
# 988  217041480  Warrnambool - South  43149.0  45726.0  47242.0  49080.0
#
#      2020-21  average_income  income_growth_rate  affluence_index  postcode  \
# 0    58036.0         54043.2            0.147047     37830.284114    3350.0
# 1    55998.0         53059.8            0.117881     37141.895364    3354.0
# 2    56408.0         52600.8            0.154081     36820.606224    3357.0
# 3    52792.0         49710.2            0.143278     34797.182983    3352.0
# 4    52792.0         49710.2            0.143278     34797.182983    3358.0
# ..       ...             ...                 ...              ...       ...
# 984  50360.0         45496.8            0.202225     31847.820667    3287.0
# 985  50360.0         45496.8            0.202225     31847.820667    3286.0
# 986  50360.0         45496.8            0.202225     31847.820667    3289.0
# 987  52518.0         48696.2            0.179941     34087.393982    3280.0
# 988  52359.0         47511.2            0.213446     33257.904034    3277.0
#
#      2021-22(pred)  2022-23(pred)  2023-24(pred)
# 0     59598.456960   61736.679369   63299.471674
# 1     55849.340973   57143.146334   56690.672918
# 2     58390.032469   60078.161740   61977.834711
# 3     53340.484044   53479.345721   53435.657234
# 4     53340.484044   53479.345721   53435.657234
# ..             ...            ...            ...
# 984   51787.538934   54570.351073   56003.012955
# 985   51787.538934   54570.351073   56003.012955
# 986   51787.538934   54570.351073   56003.012955
# 987   54318.128580   56066.440822   57780.848537
# 988   54581.254552   56942.435354   59165.005449
#
# [895 rows x 14 columns]

# %%
# Group by postcode and calculate the median predicted income for each postcode
yearly_income_grouped = yearly_income.groupby('postcode')['2023-24(pred)'].median().reset_index()

yearly_income_grouped.rename(columns={'2023-24(pred)': 'median income of 2023-24'}, inplace=True)

# Merge the result as a new median income column into the original dataframe
yearly_income = pd.merge(yearly_income, yearly_income_grouped, on='postcode')

yearly_income
# Out:
#            SA2                SA2 name  2016-17  2017-18  2018-19  2019-20  \
# 0    201011001               Alfredton  50596.0  52448.0  53932.0  55204.0
# 1    201011483  Canadian - Mount Clear  43944.0  46025.0  47887.0  48536.0
# 2    201011002                Ballarat  50093.0  51736.0  53688.0  53784.0
# 3    201011005               Buninyong  48877.0  51034.0  52377.0  54308.0
# 4    201011006               Delacombe  46176.0  47759.0  49909.0  51915.0
# ..         ...                     ...      ...      ...      ...      ...
# 890  217041478            Moyne - West  41889.0  43136.0  45256.0  46843.0
# 891  217041478            Moyne - West  41889.0  43136.0  45256.0  46843.0
# 892  217041478            Moyne - West  41889.0  43136.0  45256.0  46843.0
# 893  217041479     Warrnambool - North  44509.0  46945.0  48855.0  50654.0
# 894  217041480     Warrnambool - South  43149.0  45726.0  47242.0  49080.0
#
#      2020-21  average_income  income_growth_rate  affluence_index  postcode  \
# 0    58036.0         54043.2            0.147047     37830.284114    3350.0
# 1    50350.0         47348.4            0.145776     33143.923733    3350.0
# 2    55998.0         53059.8            0.117881     37141.895364    3354.0
# 3    56408.0         52600.8            0.154081     36820.606224    3357.0
# 4    52792.0         49710.2            0.143278     34797.182983    3352.0
# ..       ...             ...                 ...              ...       ...
# 890  50360.0         45496.8            0.202225     31847.820667    3304.0
# 891  50360.0         45496.8            0.202225     31847.820667    3301.0
# 892  50360.0         45496.8            0.202225     31847.820667    3287.0
# 893  52518.0         48696.2            0.179941     34087.393982    3280.0
# 894  52359.0         47511.2            0.213446     33257.904034    3277.0
#
#      2021-22(pred)  2022-23(pred)  2023-24(pred)  median income of 2023-24
# 0     59598.456960   61736.679369   63299.471674              57507.352645
# 1     50691.987185   51716.464491   51715.233615              57507.352645
# 2     55849.340973   57143.146334   56690.672918              56690.672918
# 3     58390.032469   60078.161740   61977.834711              61977.834711
# 4     53340.484044   53479.345721   53435.657234              52503.896743
# ..             ...            ...            ...                       ...
# 890   51787.538934   54570.351073   56003.012955              56003.012955
# 891   51787.538934   54570.351073   56003.012955              56003.012955
# 892   51787.538934   54570.351073   56003.012955              56003.012955
# 893   54318.128580   56066.440822   57780.848537              57780.848537
# 894   54581.254552   56942.435354   59165.005449              59165.005449
#
# [895 rows x 15 columns]

# %%
# select the column we need
yearly_income_selected = pd.DataFrame(yearly_income, columns=["postcode", "SA2", "median income of 2023-24"])

# %%
yearly_income_selected
# Out:
#      postcode        SA2  median income of 2023-24
# 0      3350.0  201011001              57507.352645
# 1      3350.0  201011483              57507.352645
# 2      3354.0  201011002              56690.672918
# 3      3357.0  201011005              61977.834711
# 4      3352.0  201011006              52503.896743
# ..        ...        ...                       ...
# 890    3304.0  217041478              56003.012955
# 891    3301.0  217041478              56003.012955
# 892    3287.0  217041478              56003.012955
# 893    3280.0  217041479              57780.848537
# 894    3277.0  217041480              59165.005449
#
# [895 rows x 3 columns]

# %%
yearly_income_selected['postcode'] = yearly_income_selected['postcode'].astype('int64')
yearly_income_selected
# Out:
#      postcode        SA2  median income of 2023-24
# 0        3350  201011001              57507.352645
# 1        3350  201011483              57507.352645
# 2        3354  201011002              56690.672918
# 3        3357  201011005              61977.834711
# 4        3352  201011006              52503.896743
# ..        ...        ...                       ...
# 890      3304  217041478              56003.012955
# 891      3301  217041478              56003.012955
# 892      3287  217041478              56003.012955
# 893      3280  217041479              57780.848537
# 894      3277  217041480              59165.005449
#
# [895 rows x 3 columns]

# %%
# preprocess past rent data
rent_data = pd.read_csv("../data/curated/rent_cleaned.csv", index_col=0)
rent_data_selected = pd.DataFrame(rent_data, columns=["suburb", "postcode", "latitude", "longitude", "price_per_week"])
rent_data_selected
# Out:
#                suburb  postcode   latitude   longitude  price_per_week
# 0        Mount Martha      3934 -38.268818  145.014034          1600.0
# 1      Bentleigh East      3165 -37.909091  145.055152           780.0
# 2      Ferntree Gully      3156 -37.890452  145.267922           585.0
# 3     Frankston North      3200 -38.115353  145.163260           475.0
# 4          Camberwell      3124 -37.840108  145.094830           590.0
# ...               ...       ...        ...         ...             ...
# 2957        Melbourne      3000 -37.809580  144.960120           680.0
# 2958        Melbourne      3000 -37.810002  144.958818           800.0
# 2959      Capel Sound      3940 -38.372306  144.884492           500.0
# 2960          Bendigo      3550 -36.759161  144.267363           560.0
# 2961       Mordialloc      3195 -38.008262  145.085600           450.0
#
# [2962 rows x 5 columns]

# %%
rent_data_selected.isnull().sum()
# Out:
# suburb            0
# postcode          0
# latitude          0
# longitude         0
# price_per_week    0
# dtype: int64

# %%
rent_data_selected = rent_data_selected.groupby(['postcode', 'suburb', 'latitude', 'longitude'])['price_per_week'].median().reset_index()
rent_data_selected.rename(columns={'price_per_week': 'median rent per week of 2023-24'}, inplace=True)
rent_data_selected
# Out:
#       postcode           suburb   latitude   longitude  \
# 0         3000        Melbourne -37.851214  144.980093
# 1         3000        Melbourne -37.845242  144.979642
# 2         3000        Melbourne -37.843986  144.976371
# 3         3000        Melbourne -37.842589  144.977041
# 4         3000        Melbourne -37.841987  144.975566
# ...        ...              ...        ...         ...
# 2710      3984      Pioneer Bay -38.379923  145.548373
# 2711      3995         Kilcunda -38.545338  145.459290
# 2712      3995  North Wonthaggi -38.583300  145.595902
# 2713      3995        Wonthaggi -38.618064  145.588395
# 2714      3996        Inverloch -38.632601  145.730252
#
#       median rent per week of 2023-24
# 0                               670.0
# 1                               700.0
# 2                               495.0
# 3                               480.0
# 4                               550.0
# ...                               ...
# 2710                            350.0
# 2711                            440.0
# 2712                            540.0
# 2713                            385.0
# 2714                            460.0
#
# [2715 rows x 5 columns]

# %%
# Use the weekly rent price to get the total annual rent price
rent_data_selected['median rent per week of 2023-24'] = rent_data_selected['median rent per week of 2023-24']*52
rent_data_selected
# Out:
#       postcode           suburb   latitude   longitude  \
# 0         3000        Melbourne -37.851214  144.980093
# 1         3000        Melbourne -37.845242  144.979642
# 2         3000        Melbourne -37.843986  144.976371
# 3         3000        Melbourne -37.842589  144.977041
# 4         3000        Melbourne -37.841987  144.975566
# ...        ...              ...        ...         ...
# 2710      3984      Pioneer Bay -38.379923  145.548373
# 2711      3995         Kilcunda -38.545338  145.459290
# 2712      3995  North Wonthaggi -38.583300  145.595902
# 2713      3995        Wonthaggi -38.618064  145.588395
# 2714      3996        Inverloch -38.632601  145.730252
#
#       median rent per week of 2023-24
# 0                             34840.0
# 1                             36400.0
# 2                             25740.0
# 3                             24960.0
# 4                             28600.0
# ...                               ...
# 2710                          18200.0
# 2711                          22880.0
# 2712                          28080.0
# 2713                          20020.0
# 2714                          23920.0
#
# [2715 rows x 5 columns]

# %%
combined_data = pd.merge(yearly_income_selected, rent_data_selected, on=['postcode'], how='inner')
combined_data = combined_data[['postcode', 'SA2', 'suburb', 'latitude', 'longitude', 'median income of 2023-24', 'median rent per week of 2023-24']]
combined_data
# Out:
#       postcode        SA2       suburb   latitude   longitude  \
# 0         3350  201011001    Alfredton -37.566019  143.785460
# 1         3350  201011001    Alfredton -37.565994  143.792568
# 2         3350  201011001    Alfredton -37.565575  143.798101
# 3         3350  201011001    Alfredton -37.564730  143.799695
# 4         3350  201011001    Alfredton -37.561417  143.817393
# ...        ...        ...          ...        ...         ...
# 4052      3280  217041479  Warrnambool -38.373465  142.506210
# 4053      3280  217041479  Warrnambool -38.364072  142.513889
# 4054      3280  217041479  Warrnambool -38.359425  142.512095
# 4055      3280  217041479  Warrnambool -38.357031  142.467634
# 4056      3280  217041479  Warrnambool -38.348686  142.464283
#
#       median income of 2023-24  median rent per week of 2023-24
# 0                 57507.352645                          24960.0
# 1                 57507.352645                          25480.0
# 2                 57507.352645                          23660.0
# 3                 57507.352645                          28080.0
# 4                 57507.352645                          21840.0
# ...                        ...                              ...
# 4052              57780.848537                          24960.0
# 4053              57780.848537                          36400.0
# 4054              57780.848537                          33800.0
# 4055              57780.848537                          28080.0
# 4056              57780.848537                          33800.0
#
# [4057 rows x 7 columns]

# %%
combined_data.isnull().sum()
# Out:
# postcode                           0
# SA2                                0
# suburb                             0
# latitude                           0
# longitude                          0
# median income of 2023-24           0
# median rent per week of 2023-24    0
# dtype: int64

# %%
combined_data['affordable index of 2023-24'] = combined_data['median income of 2023-24'] / combined_data['median rent per week of 2023-24']
combined_data
# Out:
#       postcode        SA2       suburb   latitude   longitude  \
# 0         3350  201011001    Alfredton -37.566019  143.785460
# 1         3350  201011001    Alfredton -37.565994  143.792568
# 2         3350  201011001    Alfredton -37.565575  143.798101
# 3         3350  201011001    Alfredton -37.564730  143.799695
# 4         3350  201011001    Alfredton -37.561417  143.817393
# ...        ...        ...          ...        ...         ...
# 4052      3280  217041479  Warrnambool -38.373465  142.506210
# 4053      3280  217041479  Warrnambool -38.364072  142.513889
# 4054      3280  217041479  Warrnambool -38.359425  142.512095
# 4055      3280  217041479  Warrnambool -38.357031  142.467634
# 4056      3280  217041479  Warrnambool -38.348686  142.464283
#
#       median income of 2023-24  median rent per week of 2023-24  \
# 0                 57507.352645                          24960.0
# 1                 57507.352645                          25480.0
# 2                 57507.352645                          23660.0
# 3                 57507.352645                          28080.0
# 4                 57507.352645                          21840.0
# ...                        ...                              ...
# 4052              57780.848537                          24960.0
# 4053              57780.848537                          36400.0
# 4054              57780.848537                          33800.0
# 4055              57780.848537                          28080.0
# 4056              57780.848537                          33800.0
#
#       affordable index of 2023-24
# 0                        2.303980
# 1                        2.256960
# 2                        2.430573
# 3                        2.047983
# 4                        2.633121
# ...                           ...
# 4052                     2.314938
# 4053                     1.587386
# 4054                     1.709493
# 4055                     2.057723
# 4056                     1.709493
#
# [4057 rows x 8 columns]

# %%
combined_data = combined_data.drop_duplicates()
combined_data
# Out:
#       postcode        SA2       suburb   latitude   longitude  \
# 0         3350  201011001    Alfredton -37.566019  143.785460
# 1         3350  201011001    Alfredton -37.565994  143.792568
# 2         3350  201011001    Alfredton -37.565575  143.798101
# 3         3350  201011001    Alfredton -37.564730  143.799695
# 4         3350  201011001    Alfredton -37.561417  143.817393
# ...        ...        ...          ...        ...         ...
# 4052      3280  217041479  Warrnambool -38.373465  142.506210
# 4053      3280  217041479  Warrnambool -38.364072  142.513889
# 4054      3280  217041479  Warrnambool -38.359425  142.512095
# 4055      3280  217041479  Warrnambool -38.357031  142.467634
# 4056      3280  217041479  Warrnambool -38.348686  142.464283
#
#       median income of 2023-24  median rent per week of 2023-24  \
# 0                 57507.352645                          24960.0
# 1                 57507.352645                          25480.0
# 2                 57507.352645                          23660.0
# 3                 57507.352645                          28080.0
# 4                 57507.352645                          21840.0
# ...                        ...                              ...
# 4052              57780.848537                          24960.0
# 4053              57780.848537                          36400.0
# 4054              57780.848537                          33800.0
# 4055              57780.848537                          28080.0
# 4056              57780.848537                          33800.0
#
#       affordable index of 2023-24
# 0                        2.303980
# 1                        2.256960
# 2                        2.430573
# 3                        2.047983
# 4                        2.633121
# ...                           ...
# 4052                     2.314938
# 4053                     1.587386
# 4054                     1.709493
# 4055                     2.057723
# 4056                     1.709493
#
# [4057 rows x 8 columns]

# %%
# save data to csv

combined_data.to_csv("../data/curated/rent_income_2023-24.csv")

# %%
# Sort by affordable index by 
top_affordable_index = combined_data.sort_values(by='affordable index of 2023-24', ascending=False)

# Find top 10 areas with affordable indexs
top_affordable_index.iloc[:10,:]
# Out:
#       postcode        SA2              suburb   latitude   longitude  \
# 621       3212  203021043                Lara -38.013475  144.401553
# 2680      3981  212011548         Koo Wee Rup -38.181543  145.469598
# 1324      3000  206041119           Melbourne -37.812024  144.969996
# 988       3058  206011497        Coburg North -37.721361  144.958501
# 994       3058  210031236        Coburg North -37.721361  144.958501
# 2260      3081  209011199  Heidelberg Heights -37.732063  145.060126
# 1678      3181  206061136             Windsor -37.853356  144.992530
# 782       3690  204031492             Wodonga -36.128816  146.863823
# 1670      3181  206061136             Prahran -37.848507  144.990328
# 3955      3396  215011394            Hopetoun -35.733631  142.366467
#
#       median income of 2023-24  median rent per week of 2023-24  \
# 621               60759.903158                          10400.0
# 2680              60515.983555                          10400.0
# 1324              88862.163133                          16120.0
# 988               62347.983754                          11440.0
# 994               62347.983754                          11440.0
# 2260              62008.956946                          11440.0
# 1678              81175.176456                          15080.0
# 782               55626.836071                          10400.0
# 1670              81175.176456                          15990.0
# 3955              52549.283369                          10400.0
#
#       affordable index of 2023-24
# 621                      5.842298
# 2680                     5.818845
# 1324                     5.512541
# 988                      5.449999
# 994                      5.449999
# 2260                     5.420363
# 1678                     5.382969
# 782                      5.348734
# 1670                     5.076621
# 3955                     5.052816

# %%
duplicates = top_affordable_index[top_affordable_index.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [postcode, SA2, suburb, latitude, longitude, median income of 2023-24, median rent per week of 2023-24, affordable index of 2023-24]
# Index: []

# %%
import folium

# Create the base map, setting the center location
m = folium.Map(location=[-37.8136, 144.9631], zoom_start=10)  # Melbourne city center, adjust as needed

# Loop through the top 10 most affordable areas
for idx, row in top_affordable_index.iloc[:10].iterrows():
    # Create a marker; location parameter can be latitude and longitude for each area
    # Assume that you have latitude and longitude coordinates for each suburb or postcode
    folium.Marker(
        location=[row['latitude'], row['longitude']],  # Use coordinates based on the postcode
        popup=f"{row['suburb']} (Affordable Index: {row['affordable index of 2023-24']:.2f})",
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_490750b020ab4d1001fdd85ed1c6fb98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_490750b020ab4d1001fdd85ed1c6fb98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_490750b020ab4d1001fdd85ed1c6fb98 = L.map(
#                 &quot;map_490750b020ab4d1001fdd85ed1c6fb98&quot;,
#                 {
#                     center: [-37.8136, 144.9631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_730ae788a8f7d6cee6952b89b15d5650 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_730ae788a8f7d6cee6952b89b15d5650.addTo(map_490750b020ab4d1001fdd85ed1c6fb98);
#
#
#             var marker_818c0ab618b3708c29a41a16599a4a1a = L.marker(
#                 [-38.0134753, 144.4015528],
#                 {}
#             ).addTo(map_490750b020ab4d1001fdd85ed1c6fb98);
#
#
#         var popup_48fb63006821e2127339fcb61f00cdbf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14bd73616d31e7b7d506d406892caaa6 = $(`&lt;div id=&quot;html_14bd73616d31e7b7d506d406892caaa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lara (Affordable Index: 5.84)&lt;/div&gt;`)[0];
#                 popup_48fb63006821e2127339fcb61f00cdbf.setContent(html_14bd73616d31e7b7d506d406892caaa6);
#
#
#
#         marker_818c0ab618b3708c29a41a16599a4a1a.bindPopup(popup_48fb63006821e2127339fcb61f00cdbf)
#         ;
#
#
#
#
#             var marker_a257b7ad7120580085766a3b7a18c20e = L.marker(
#                 [-38.181543, 145.4695976],
#                 {}
#             ).addTo(map_490750b020ab4d1001fdd85ed1c6fb98);
#
#
#         var popup_780f72d2b4f5bf8348cb3c6e1289bc05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd31d22c3a9ab46d65ffbdfb205bf82f = $(`&lt;div id=&quot;html_bd31d22c3a9ab46d65ffbdfb205bf82f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Koo Wee Rup (Affordable Index: 5.82)&lt;/div&gt;`)[0];
#                 popup_780f72d2b4f5bf8348cb3c6e1289bc05.setContent(html_bd31d22c3a9ab46d65ffbdfb205bf82f);
#
#
#
#         marker_a257b7ad7120580085766a3b7a18c20e.bindPopup(popup_780f72d2b4f5bf8348cb3c6e1289bc05)
#         ;
#
#
#
#
#             var marker_f59e744649a98f946de38226f031d7a6 = L.marker(
#                 [-37.8120241, 144.9699956],
#                 {}
#             ).addTo(map_490750b020ab4d1001fdd85ed1c6fb98);
#
#
#         var popup_9f7f7644e74d3d8ed1ae538e22c742f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b86daeb5273e92601340839a2eb09b0 = $(`&lt;div id=&quot;html_7b86daeb5273e92601340839a2eb09b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Melbourne (Affordable Index: 5.51)&lt;/div&gt;`)[0];
#                 popup_9f7f7644e74d3d8ed1ae538e22c742f5.setContent(html_7b86daeb5273e92601340839a2eb09b0);
#
#
#
#         marker_f59e744649a98f946de38226f031d7a6.bindPopup(popup_9f7f7644e74d3d8ed1ae538e22c742f5)
#         ;
#
#
#
#
#             var marker_8aa12b75ea10e3ac3c041da2d37a4bc5 = L.marker(
#                 [-37.7213611, 144.9585014],
#                 {}
#             ).addTo(map_490750b020ab4d1001fdd85ed1c6fb98);
#
#
#         var popup_cbc9f343161cc24845a1f28c746fda7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54bce657b1a9c97519bd44fb8caf16f4 = $(`&lt;div id=&quot;html_54bce657b1a9c97519bd44fb8caf16f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coburg North (Affordable Index: 5.45)&lt;/div&gt;`)[0];
#                 popup_cbc9f343161cc24845a1f28c746fda7b.setContent(html_54bce657b1a9c97519bd44fb8caf16f4);
#
#
#
#         marker_8aa12b75ea10e3ac3c041da2d37a4bc5.bindPopup(popup_cbc9f343161cc24845a1f28c746fda7b)
#         ;
#
#
#
#
#             var marker_05c4235b9b937a39203a73fabe72b333 = L.marker(
#                 [-37.7213611, 144.9585014],
#                 {}
#             ).addTo(map_490750b020ab4d1001fdd85ed1c6fb98);
#
#
#         var popup_6500ff4ef747d709e4c6a36a3c59e955 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4335fb01906556438b62d7329dc5d7ec = $(`&lt;div id=&quot;html_4335fb01906556438b62d7329dc5d7ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coburg North (Affordable Index: 5.45)&lt;/div&gt;`)[0];
#                 popup_6500ff4ef747d709e4c6a36a3c59e955.setContent(html_4335fb01906556438b62d7329dc5d7ec);
#
#
#
#         marker_05c4235b9b937a39203a73fabe72b333.bindPopup(popup_6500ff4ef747d709e4c6a36a3c59e955)
#         ;
#
#
#
#
#             var marker_12488c4bd05b0e89bc423a5c0d29f740 = L.
