# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# Model Feature selection

# %%
data_path = Path.cwd().parent/'data'/'curated'/'past_rent_income_population.csv'
rent_df = pd.read_csv(data_path)

# %%
pd.set_option('display.max_columns', None)
rent_df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0_x                                 suburb  \
# 0           0             2  Albert Park-Middle Park-West St Kilda
# 1           1             2  Albert Park-Middle Park-West St Kilda
# 2           2             2  Albert Park-Middle Park-West St Kilda
# 3           3             2  Albert Park-Middle Park-West St Kilda
# 4           4             3                               Armadale
#
#    2000-YearlyCount  2000-YearlyMedian  2001-YearlyCount  2001-YearlyMedian  \
# 0            4632.0             266.25            4990.0             281.25
# 1            4632.0             266.25            4990.0             281.25
# 2            4632.0             266.25            4990.0             281.25
# 3            4632.0             266.25            4990.0             281.25
# 4            2947.0             203.75            2904.0             222.50
#
#    2002-YearlyCount  2002-YearlyMedian  2003-YearlyCount  2003-YearlyMedian  \
# 0              4097              300.0              6844              295.0
# 1              4097              300.0              6844              295.0
# 2              4097              300.0              6844              295.0
# 3              4097              300.0              6844              295.0
# 4              2330              231.0              3729              236.0
#
#    2004-YearlyCount  2004-YearlyMedian  2005-YearlyCount  2005-YearlyMedian  \
# 0              4963             300.00              5048             302.50
# 1              4963             300.00              5048             302.50
# 2              4963             300.00              5048             302.50
# 3              4963             300.00              5048             302.50
# 4              2839             238.75              2779             243.25
#
#    2006-YearlyCount  2006-YearlyMedian  2007-YearlyCount  2007-YearlyMedian  \
# 0              4101             317.00              3430              362.5
# 1              4101             317.00              3430              362.5
# 2              4101             317.00              3430              362.5
# 3              4101             317.00              3430              362.5
# 4              2684             261.25              2548              295.0
#
#    2008-YearlyCount  2008-YearlyMedian  2009-YearlyCount  2009-YearlyMedian  \
# 0              3609             389.50              3690             417.50
# 1              3609             389.50              3690             417.50
# 2              3609             389.50              3690             417.50
# 3              3609             389.50              3690             417.50
# 4              2560             331.25              2316             350.75
#
#    2010-YearlyCount  2010-YearlyMedian  2011-YearlyCount  2011-YearlyMedian  \
# 0              3849             431.25              3666              445.0
# 1              3849             431.25              3666              445.0
# 2              3849             431.25              3666              445.0
# 3              3849             431.25              3666              445.0
# 4              2425             363.75              2580              382.5
#
#    2012-YearlyCount  2012-YearlyMedian  2013-YearlyCount  2013-YearlyMedian  \
# 0              3892              460.0              3894              461.5
# 1              3892              460.0              3894              461.5
# 2              3892              460.0              3894              461.5
# 3              3892              460.0              3894              461.5
# 4              2422              385.0              2515              395.0
#
#    2014-YearlyCount  2014-YearlyMedian  2015-YearlyCount  2015-YearlyMedian  \
# 0              4044             472.50              3721             491.25
# 1              4044             472.50              3721             491.25
# 2              4044             472.50              3721             491.25
# 3              4044             472.50              3721             491.25
# 4              2685             393.75              2665             399.75
#
#    2016-YearlyCount  2016-YearlyMedian  2017-YearlyCount  2017-YearlyMedian  \
# 0              3823              515.0              3600             527.75
# 1              3823              515.0              3600             527.75
# 2              3823              515.0              3600             527.75
# 3              3823              515.0              3600             527.75
# 4              2645              402.5              3122             445.00
#
#    2018-YearlyCount  2018-YearlyMedian  2019-YearlyCount  2019-YearlyMedian  \
# 0              3649              562.5              3495             568.00
# 1              3649              562.5              3495             568.00
# 2              3649              562.5              3495             568.00
# 3              3649              562.5              3495             568.00
# 4              3667              487.5              3067             481.25
#
#    2020-YearlyCount  2020-YearlyMedian  2021-YearlyCount  2021-YearlyMedian  \
# 0              3342             570.00              3695             498.75
# 1              3342             570.00              3695             498.75
# 2              3342             570.00              3695             498.75
# 3              3342             570.00              3695             498.75
# 4              2977             498.75              3289             433.75
#
#    2022-YearlyCount  2022-YearlyMedian  postcode  Unnamed: 0.1   SA2 code  \
# 0              3435              510.0    3004.0           334  206041119
# 1              3435              510.0    3004.0           346  206041125
# 2              3435              510.0    3004.0           362  206051128
# 3              3435              510.0    3004.0           368  206051513
# 4              3348              447.5    3143.0           370  206061135
#
#              SA2 name   2001   2002   2003   2004   2005   2006   2007   2008  \
# 0      East Melbourne   3731   3859   4243   4460   4495   4555   4806   5055
# 1  South Yarra - West   5317   5233   5176   5183   5289   5538   5837   6118
# 2         Albert Park  12368  12595  12800  12997  13269  13550  13731  13928
# 3  St Kilda - Central   8558   8675   8836   8965   9145   9340   9650   9924
# 4            Armadale   8632   8683   8724   8770   8783   8863   8990   9148
#
#     2009   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 0   5202   5272   5238   5280   5333   5374   5411   5475   5496   5412
# 1   6380   6418   6426   6400   6393   6397   6405   6453   6833   6957
# 2  14245  14595  15009  15142  15282  15592  16053  16490  16500  16728
# 3  10268  10494  10751  11323  11798  12234  12561  13014  13315  13589
# 4   9260   9318   9301   9308   9338   9387   9485   9619   9635   9906
#
#     2019   2020   2021   2022   2023  population_growth_rate          2024  \
# 0   5416   5383   4959   4889   5100                0.014868   5175.824488
# 1   7055   6960   6536   6573   6789                0.011538   6867.332701
# 2  17081  16955  16011  16177  16861                0.014356  17103.056186
# 3  13676  13380  12086  12256  13186                0.020345  13454.264995
# 4  10044  10075   9433   9376   9769                0.005810   9825.761894
#
#            2025          2026          2027          2028  Unnamed: 0_y  \
# 0   5252.776301   5330.872198   5410.129189   5490.564538           129
# 1   6946.569219   7026.719983   7107.795540   7189.806561           133
# 2  17348.587326  17597.643306  17850.274728  18106.532923           143
# 3  13727.987756  14007.279320  14292.252982  14583.024344           149
# 4   9882.853598   9940.277028   9998.034111  10056.126787           151
#
#          SA2            SA2 NAME  2016-17  2017-18  2018-19  2019-20  2020-21  \
# 0  206041119      East Melbourne  69469.0  71759.0  75755.0  77804.0  81648.0
# 1  206041125  South Yarra - West  64865.0  68512.0  70451.0  69578.0  72567.0
# 2  206051128         Albert Park  65352.0  66627.0  67518.0  68933.0  73107.0
# 3  206051513  St Kilda - Central  53464.0  56940.0  59644.0  60523.0  64644.0
# 4  206061135            Armadale  63296.0  66098.0  69563.0  72012.0  73321.0
#
#    average_income  income_growth_rate  affluence_index  \
# 0         75287.0            0.175316     52700.952595
# 1         69194.6            0.118739     48436.255622
# 2         68307.4            0.118665     47815.215600
# 3         59043.0            0.209113     41330.162734
# 4         68858.0            0.158383     48200.647515
#
#                                             geometry
# 0  POLYGON ((144.9739585748236 -37.81330241814959...
# 1  POLYGON ((144.97455041239857 -37.8346653683224...
# 2  POLYGON ((144.96766973330057 -37.8373669078686...
# 3  POLYGON ((144.9822465081365 -37.86154000901546...
# 4  POLYGON ((145.01167433388778 -37.8535692509816...

# %%
rent_df = rent_df.drop(['Unnamed: 0', 'Unnamed: 0_x', 'Unnamed: 0.1', 'SA2 code','SA2 name','Unnamed: 0_y'], axis=1)

# %%
rent_df.head(2)
# Out:
#                                   suburb  2000-YearlyCount  2000-YearlyMedian  \
# 0  Albert Park-Middle Park-West St Kilda            4632.0             266.25
# 1  Albert Park-Middle Park-West St Kilda            4632.0             266.25
#
#    2001-YearlyCount  2001-YearlyMedian  2002-YearlyCount  2002-YearlyMedian  \
# 0            4990.0             281.25              4097              300.0
# 1            4990.0             281.25              4097              300.0
#
#    2003-YearlyCount  2003-YearlyMedian  2004-YearlyCount  2004-YearlyMedian  \
# 0              6844              295.0              4963              300.0
# 1              6844              295.0              4963              300.0
#
#    2005-YearlyCount  2005-YearlyMedian  2006-YearlyCount  2006-YearlyMedian  \
# 0              5048              302.5              4101              317.0
# 1              5048              302.5              4101              317.0
#
#    2007-YearlyCount  2007-YearlyMedian  2008-YearlyCount  2008-YearlyMedian  \
# 0              3430              362.5              3609              389.5
# 1              3430              362.5              3609              389.5
#
#    2009-YearlyCount  2009-YearlyMedian  2010-YearlyCount  2010-YearlyMedian  \
# 0              3690              417.5              3849             431.25
# 1              3690              417.5              3849             431.25
#
#    2011-YearlyCount  2011-YearlyMedian  2012-YearlyCount  2012-YearlyMedian  \
# 0              3666              445.0              3892              460.0
# 1              3666              445.0              3892              460.0
#
#    2013-YearlyCount  2013-YearlyMedian  2014-YearlyCount  2014-YearlyMedian  \
# 0              3894              461.5              4044              472.5
# 1              3894              461.5              4044              472.5
#
#    2015-YearlyCount  2015-YearlyMedian  2016-YearlyCount  2016-YearlyMedian  \
# 0              3721             491.25              3823              515.0
# 1              3721             491.25              3823              515.0
#
#    2017-YearlyCount  2017-YearlyMedian  2018-YearlyCount  2018-YearlyMedian  \
# 0              3600             527.75              3649              562.5
# 1              3600             527.75              3649              562.5
#
#    2019-YearlyCount  2019-YearlyMedian  2020-YearlyCount  2020-YearlyMedian  \
# 0              3495              568.0              3342              570.0
# 1              3495              568.0              3342              570.0
#
#    2021-YearlyCount  2021-YearlyMedian  2022-YearlyCount  2022-YearlyMedian  \
# 0              3695             498.75              3435              510.0
# 1              3695             498.75              3435              510.0
#
#    postcode  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# 0    3004.0  3731  3859  4243  4460  4495  4555  4806  5055  5202  5272  5238
# 1    3004.0  5317  5233  5176  5183  5289  5538  5837  6118  6380  6418  6426
#
#    2012  2013  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023  \
# 0  5280  5333  5374  5411  5475  5496  5412  5416  5383  4959  4889  5100
# 1  6400  6393  6397  6405  6453  6833  6957  7055  6960  6536  6573  6789
#
#    population_growth_rate         2024         2025         2026         2027  \
# 0                0.014868  5175.824488  5252.776301  5330.872198  5410.129189
# 1                0.011538  6867.332701  6946.569219  7026.719983  7107.795540
#
#           2028        SA2            SA2 NAME  2016-17  2017-18  2018-19  \
# 0  5490.564538  206041119      East Melbourne  69469.0  71759.0  75755.0
# 1  7189.806561  206041125  South Yarra - West  64865.0  68512.0  70451.0
#
#    2019-20  2020-21  average_income  income_growth_rate  affluence_index  \
# 0  77804.0  81648.0         75287.0            0.175316     52700.952595
# 1  69578.0  72567.0         69194.6            0.118739     48436.255622
#
#                                             geometry
# 0  POLYGON ((144.9739585748236 -37.81330241814959...
# 1  POLYGON ((144.97455041239857 -37.8346653683224...

# %%
# Rename YearlyCount columns
rent_df.rename(columns={f"{year}-YearlyCount": f"{year}_rent_count" for year in range(2000, 2023)}, inplace=True)

# Rename YearlyMedian columns
rent_df.rename(columns={f"{year}-YearlyMedian": f"{year}_rent_median" for year in range(2000, 2023)}, inplace=True)

# Rename population columns
rent_df.rename(columns={str(year): f"{year}_population" for year in range(2001, 2029)}, inplace=True)

# Rename income columns
income_rename_dict = {
    "2016-17": "2016_income",
    "2017-18": "2017_income",
    "2018-19": "2018_income",
    "2019-20": "2019_income",
    "2020-21": "2020_income"
}
rent_df.rename(columns=income_rename_dict, inplace=True)

# Reorder columns
cols = rent_df.columns.tolist()  # Get the current columns as a list

# Specify the new order
new_order = ['suburb', 'postcode', 'SA2', 'SA2 NAME', 'geometry'] + [col for col in cols if col not in ['suburb', 'postcode', 'SA2', 'SA2 NAME']]

# Reorder the DataFrame
rent_df = rent_df[new_order]

# %%
rent_df.head(1)
# Out:
#                                   suburb  postcode        SA2        SA2 NAME  \
# 0  Albert Park-Middle Park-West St Kilda    3004.0  206041119  East Melbourne
#
#                                             geometry  2000_rent_count  \
# 0  POLYGON ((144.9739585748236 -37.81330241814959...           4632.0
#
#    2000_rent_median  2001_rent_count  2001_rent_median  2002_rent_count  \
# 0            266.25           4990.0            281.25             4097
#
#    2002_rent_median  2003_rent_count  2003_rent_median  2004_rent_count  \
# 0             300.0             6844             295.0             4963
#
#    2004_rent_median  2005_rent_count  2005_rent_median  2006_rent_count  \
# 0             300.0             5048             302.5             4101
#
#    2006_rent_median  2007_rent_count  2007_rent_median  2008_rent_count  \
# 0             317.0             3430             362.5             3609
#
#    2008_rent_median  2009_rent_count  2009_rent_median  2010_rent_count  \
# 0             389.5             3690             417.5             3849
#
#    2010_rent_median  2011_rent_count  2011_rent_median  2012_rent_count  \
# 0            431.25             3666             445.0             3892
#
#    2012_rent_median  2013_rent_count  2013_rent_median  2014_rent_count  \
# 0             460.0             3894             461.5             4044
#
#    2014_rent_median  2015_rent_count  2015_rent_median  2016_rent_count  \
# 0             472.5             3721            491.25             3823
#
#    2016_rent_median  2017_rent_count  2017_rent_median  2018_rent_count  \
# 0             515.0             3600            527.75             3649
#
#    2018_rent_median  2019_rent_count  2019_rent_median  2020_rent_count  \
# 0             562.5             3495             568.0             3342
#
#    2020_rent_median  2021_rent_count  2021_rent_median  2022_rent_count  \
# 0             570.0             3695            498.75             3435
#
#    2022_rent_median  2001_population  2002_population  2003_population  \
# 0             510.0             3731             3859             4243
#
#    2004_population  2005_population  2006_population  2007_population  \
# 0             4460             4495             4555             4806
#
#    2008_population  2009_population  2010_population  2011_population  \
# 0             5055             5202             5272             5238
#
#    2012_population  2013_population  2014_population  2015_population  \
# 0             5280             5333             5374             5411
#
#    2016_population  2017_population  2018_population  2019_population  \
# 0             5475             5496             5412             5416
#
#    2020_population  2021_population  2022_population  2023_population  \
# 0             5383             4959             4889             5100
#
#    population_growth_rate  2024_population  2025_population  2026_population  \
# 0                0.014868      5175.824488      5252.776301      5330.872198
#
#    2027_population  2028_population  2016_income  2017_income  2018_income  \
# 0      5410.129189      5490.564538      69469.0      71759.0      75755.0
#
#    2019_income  2020_income  average_income  income_growth_rate  \
# 0      77804.0      81648.0         75287.0            0.175316
#
#    affluence_index                                           geometry
# 0     52700.952595  POLYGON ((144.9739585748236 -37.81330241814959...

# %%
rent_df.to_csv(Path.cwd().parent/'data'/'curated'/'training_data_raw.csv', index=False)
cols = rent_df.columns.tolist()
print(cols)
# Out:
# ['suburb', 'postcode', 'SA2', 'SA2 NAME', 'geometry', '2000_rent_count', '2000_rent_median', '2001_rent_count', '2001_rent_median', '2002_rent_count', '2002_rent_median', '2003_rent_count', '2003_rent_median', '2004_rent_count', '2004_rent_median', '2005_rent_count', '2005_rent_median', '2006_rent_count', '2006_rent_median', '2007_rent_count', '2007_rent_median', '2008_rent_count', '2008_rent_median', '2009_rent_count', '2009_rent_median', '2010_rent_count', '2010_rent_median', '2011_rent_count', '2011_rent_median', '2012_rent_count', '2012_rent_median', '2013_rent_count', '2013_rent_median', '2014_rent_count', '2014_rent_median', '2015_rent_count', '2015_rent_median', '2016_rent_count', '2016_rent_median', '2017_rent_count', '2017_rent_median', '2018_rent_count', '2018_rent_median', '2019_rent_count', '2019_rent_median', '2020_rent_count', '2020_rent_median', '2021_rent_count', '2021_rent_median', '2022_rent_count', '2022_rent_median', '2001_population', '2002_population', '2003_population', '2004_population', '2005_population', '2006_population', '2007_population', '2008_population', '2009_population', '2010_population', '2011_population', '2012_population', '2013_population', '2014_population', '2015_population', '2016_population', '2017_population', '2018_population', '2019_population', '2020_population', '2021_population', '2022_population', '2023_population', 'population_growth_rate', '2024_population', '2025_population', '2026_population', '2027_population', '2028_population', '2016_income', '2017_income', '2018_income', '2019_income', '2020_income', 'average_income', 'income_growth_rate', 'affluence_index', 'geometry']

# %%
# Import necessary libraries for data manipulation, visualization, and modeling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression, RFE
from sklearn.linear_model import LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# Feature Selection for Rent Median Prediction

# %%
# Exclude identifier columns and target variable from features
exclude_cols = ['suburb', 'postcode', 'SA2', 'SA2 NAME', 'geometry']

# Define the target variable for rent median prediction
target_rent_median = '2022_rent_median'

# Add the target variable to the exclude list
exclude_cols += [target_rent_median]

# Define all potential features for rent median prediction
features_median = [col for col in rent_df.columns if col not in exclude_cols]

# Display the features list for verification
print("Features used for rent median prediction:")
print(features_median)
# Out:
# Features used for rent median prediction:
# ['2000_rent_count', '2000_rent_median', '2001_rent_count', '2001_rent_median', '2002_rent_count', '2002_rent_median', '2003_rent_count', '2003_rent_median', '2004_rent_count', '2004_rent_median', '2005_rent_count', '2005_rent_median', '2006_rent_count', '2006_rent_median', '2007_rent_count', '2007_rent_median', '2008_rent_count', '2008_rent_median', '2009_rent_count', '2009_rent_median', '2010_rent_count', '2010_rent_median', '2011_rent_count', '2011_rent_median', '2012_rent_count', '2012_rent_median', '2013_rent_count', '2013_rent_median', '2014_rent_count', '2014_rent_median', '2015_rent_count', '2015_rent_median', '2016_rent_count', '2016_rent_median', '2017_rent_count', '2017_rent_median', '2018_rent_count', '2018_rent_median', '2019_rent_count', '2019_rent_median', '2020_rent_count', '2020_rent_median', '2021_rent_count', '2021_rent_median', '2022_rent_count', '2001_population', '2002_population', '2003_population', '2004_population', '2005_population', '2006_population', '2007_population', '2008_population', '2009_population', '2010_population', '2011_population', '2012_population', '2013_population', '2014_population', '2015_population', '2016_population', '2017_population', '2018_population', '2019_population', '2020_population', '2021_population', '2022_population', '2023_population', 'population_growth_rate', '2024_population', '2025_population', '2026_population', '2027_population', '2028_population', '2016_income', '2017_income', '2018_income', '2019_income', '2020_income', 'average_income', 'income_growth_rate', 'affluence_index']

# %%
# Perform EDA to understand the relationships between features and the rent median

# Calculate correlation matrix between features and the target variable
corr_matrix_median = rent_df[features_median + [target_rent_median]].corr()

# Extract correlations with the target variable
corr_with_target_median = corr_matrix_median[target_rent_median].drop(target_rent_median, errors='ignore')

# Visualize the correlations using a bar plot
plt.figure(figsize=(16, 8))
corr_with_target_median.sort_values(ascending=False).plot(kind='bar')
plt.title('Correlation of Features with Rent Median')
plt.ylabel('Correlation Coefficient')
plt.show()

# %%
# Use statistical tests to select features with the strongest relationships with rent median

# Separate features and target
X_median = rent_df[features_median]
y_median = rent_df[target_rent_median]

# Handle missing values
X_median = X_median.fillna(0)
y_median = y_median.fillna(y_median.mean())

# Standardize features
scaler_median = StandardScaler()
X_median_scaled = scaler_median.fit_transform(X_median)

# Select top 20 features using the f_regression statistical test
selector_median = SelectKBest(score_func=f_regression, k=20)
selector_median.fit(X_median_scaled, y_median)
selected_indices_median = selector_median.get_support(indices=True)
selected_features_univariate_median = X_median.columns[selected_indices_median]

print("Top features for rent median based on univariate selection:")
print(selected_features_univariate_median.tolist())
# Out:
# Top features for rent median based on univariate selection:
# ['2002_rent_median', '2003_rent_median', '2004_rent_median', '2005_rent_median', '2006_rent_median', '2007_rent_median', '2008_rent_median', '2009_rent_median', '2010_rent_median', '2011_rent_median', '2012_rent_median', '2013_rent_median', '2014_rent_median', '2015_rent_median', '2016_rent_median', '2017_rent_median', '2018_rent_median', '2019_rent_median', '2020_rent_median', '2021_rent_median']

# %%
# Use LassoCV to select features based on their coefficients for rent median prediction

# Initialize and fit the LassoCV model
lasso_median = LassoCV(cv=5, random_state=42)
lasso_median.fit(X_median_scaled, y_median)

# Get coefficients from the Lasso model
lasso_coefficients_median = pd.Series(lasso_median.coef_, index=X_median.columns)

# Select features with non-zero coefficients
selected_features_lasso_median = lasso_coefficients_median[lasso_coefficients_median != 0].index.tolist()

print("Features selected by Lasso Regression for rent median:")
print(selected_features_lasso_median)
# Out:
# Features selected by Lasso Regression for rent median:
# ['2021_rent_median']

# %%
# Use Random Forest Regressor to determine feature importance for rent median prediction

# Initialize and fit the Random Forest model
rf_median = RandomForestRegressor(n_estimators=100, random_state=42)
rf_median.fit(X_median, y_median)

# Get feature importances from the Random Forest model
importances_median = pd.Series(rf_median.feature_importances_, index=X_median.columns)

# Select the top 20 features based on importance
selected_features_rf_median = importances_median.sort_values(ascending=False).head(20).index.tolist()

print("Top features for rent median based on Random Forest:")
print(selected_features_rf_median)
# Out:
# Top features for rent median based on Random Forest:
# ['2021_rent_median', '2020_rent_median', '2018_rent_median', '2019_rent_median', '2012_rent_median', '2014_rent_median', '2015_rent_median', 'income_growth_rate', '2017_rent_median', '2009_rent_median', '2022_rent_count', '2016_rent_median', '2014_rent_count', '2001_rent_median', '2008_rent_median', '2020_rent_count', '2007_rent_median', '2021_rent_count', '2011_rent_median', 'population_growth_rate']

# %%
# Use RFE with Random Forest to select features for rent median prediction

# Initialize the RFE model
rfe_selector_median = RFE(estimator=RandomForestRegressor(n_estimators=100, random_state=42), n_features_to_select=20, step=1)
rfe_selector_median.fit(X_median, y_median)

# Get the selected features
selected_features_rfe_median = X_median.columns[rfe_selector_median.support_].tolist()

print("Features selected by RFE for rent median:")
print(selected_features_rfe_median)
# Out:
# Features selected by RFE for rent median:
# ['2005_rent_median', '2007_rent_count', '2007_rent_median', '2009_rent_median', '2010_rent_median', '2011_rent_count', '2011_rent_median', '2014_rent_median', '2015_rent_median', '2016_rent_median', '2018_rent_median', '2019_rent_count', '2019_rent_median', '2020_rent_count', '2020_rent_median', '2021_rent_median', '2022_rent_count', '2005_population', 'population_growth_rate', 'income_growth_rate']

# %%
# Combine features selected by different methods for rent median prediction

# Combine selected features into a set to avoid duplicates
selected_features_median = set(selected_features_univariate_median) | set(selected_features_lasso_median) | set(selected_features_rf_median) | set(selected_features_rfe_median)

# Convert the set back to a list
final_selected_features_median = list(selected_features_median)

print("Final selected features for rent median prediction:")
print(final_selected_features_median)
# Out:
# Final selected features for rent median prediction:
# ['2022_rent_count', '2021_rent_median', '2011_rent_median', '2015_rent_median', '2001_rent_median', '2014_rent_median', '2007_rent_count', '2019_rent_median', '2008_rent_median', '2005_rent_median', '2020_rent_count', '2007_rent_median', '2010_rent_median', '2012_rent_median', 'population_growth_rate', '2011_rent_count', '2017_rent_median', '2002_rent_median', '2020_rent_median', '2016_rent_median', '2021_rent_count', '2013_rent_median', '2014_rent_count', '2009_rent_median', '2018_rent_median', '2004_rent_median', '2003_rent_median', 'income_growth_rate', '2005_population', '2019_rent_count', '2006_rent_median']

# %%
# Create new features or transformations for rent median prediction

# For example, calculate rent median growth rates
for year in range(2001, 2023):
    current_year = f"{year}_rent_median"
    previous_year = f"{year - 1}_rent_median"
    growth_rate_col = f"{year}_rent_median_growth"
    if current_year in rent_df.columns and previous_year in rent_df.columns:
        rent_df[growth_rate_col] = (rent_df[current_year] - rent_df[previous_year]) / rent_df[previous_year]

# Add new growth rate features to the features list
growth_features_median = [col for col in rent_df.columns if '_rent_median_growth' in col]
final_selected_features_median += growth_features_median
final_selected_features_median = list(set(final_selected_features_median))

# %%
# Prepare the final dataset for modeling rent median

# Extract the selected features and target variable
X_final_median = rent_df[final_selected_features_median]
y_final_median = rent_df[target_rent_median]

# Handle missing values
X_final_median = X_final_median.fillna(0)
y_final_median = y_final_median.fillna(y_final_median.mean())

# %% [markdown]
# Feature Selection for Rent Count Prediction

# %%
# Exclude identifier columns and target variable from features
exclude_cols = ['suburb', 'postcode', 'SA2', 'SA2 NAME', 'geometry']

# Define the target variable for rent count prediction
target_rent_count = '2022_rent_count'

# Add the target variable to the exclude list
exclude_cols += [target_rent_count]

# Define all potential features for rent count prediction
features_count = [col for col in rent_df.columns if col not in exclude_cols and not col.startswith(('2024', '2025', '2026'))]

# Display the features list for verification
print("Features used for rent count prediction:")
print(features_count)
# Out:
# Features used for rent count prediction:
# ['2000_rent_count', '2000_rent_median', '2001_rent_count', '2001_rent_median', '2002_rent_count', '2002_rent_median', '2003_rent_count', '2003_rent_median', '2004_rent_count', '2004_rent_median', '2005_rent_count', '2005_rent_median', '2006_rent_count', '2006_rent_median', '2007_rent_count', '2007_rent_median', '2008_rent_count', '2008_rent_median', '2009_rent_count', '2009_rent_median', '2010_rent_count', '2010_rent_median', '2011_rent_count', '2011_rent_median', '2012_rent_count', '2012_rent_median', '2013_rent_count', '2013_rent_median', '2014_rent_count', '2014_rent_median', '2015_rent_count', '2015_rent_median', '2016_rent_count', '2016_rent_median', '2017_rent_count', '2017_rent_median', '2018_rent_count', '2018_rent_median', '2019_rent_count', '2019_rent_median', '2020_rent_count', '2020_rent_median', '2021_rent_count', '2021_rent_median', '2022_rent_median', '2001_population', '2002_population', '2003_population', '2004_population', '2005_population', '2006_population', '2007_population', '2008_population', '2009_population', '2010_population', '2011_population', '2012_population', '2013_population', '2014_population', '2015_population', '2016_population', '2017_population', '2018_population', '2019_population', '2020_population', '2021_population', '2022_population', '2023_population', 'population_growth_rate', '2027_population', '2028_population', '2016_income', '2017_income', '2018_income', '2019_income', '2020_income', 'average_income', 'income_growth_rate', 'affluence_index', '2001_rent_median_growth', '2002_rent_median_growth', '2003_rent_median_growth', '2004_rent_median_growth', '2005_rent_median_growth', '2006_rent_median_growth', '2007_rent_median_growth', '2008_rent_median_growth', '2009_rent_median_growth', '2010_rent_median_growth', '2011_rent_median_growth', '2012_rent_median_growth', '2013_rent_median_growth', '2014_rent_median_growth', '2015_rent_median_growth', '2016_rent_median_growth', '2017_rent_median_growth', '2018_rent_median_growth', '2019_rent_median_growth', '2020_rent_median_growth', '2021_rent_median_growth', '2022_rent_median_growth']

# %%
# Perform EDA to understand the relationships between features and the rent count

# Calculate correlation matrix between features and the target variable
corr_matrix_count = rent_df[features_count + [target_rent_count]].corr()

# Extract correlations with the target variable
corr_with_target_count = corr_matrix_count[target_rent_count].drop(target_rent_count, errors='ignore')

# Visualize the correlations using a bar plot
plt.figure(figsize=(16, 8))
corr_with_target_count.sort_values(ascending=False).plot(kind='bar')
plt.title('Correlation of Features with Rent Count')
plt.ylabel('Correlation Coefficient')
plt.show()

# %%
# Use statistical tests to select features with the strongest relationships with rent count

# Separate features and target
X_count = rent_df[features_count]
y_count = rent_df[target_rent_count]

# Handle missing values
X_count = X_count.fillna(0)
y_count = y_count.fillna(y_count.mean())

# Standardize features
scaler_count = StandardScaler()
X_count_scaled = scaler_count.fit_transform(X_count)

# Select top 20 features using the f_regression statistical test
selector_count = SelectKBest(score_func=f_regression, k=20)
selector_count.fit(X_count_scaled, y_count)
selected_indices_count = selector_count.get_support(indices=True)
selected_features_univariate_count = X_count.columns[selected_indices_count]

print("Top features for rent count based on univariate selection:")
print(selected_features_univariate_count.tolist())
# Out:
# Top features for rent count based on univariate selection:
# ['2002_rent_count', '2003_rent_count', '2004_rent_count', '2005_rent_count', '2006_rent_count', '2007_rent_count', '2008_rent_count', '2009_rent_count', '2010_rent_count', '2011_rent_count', '2012_rent_count', '2013_rent_count', '2014_rent_count', '2015_rent_count', '2016_rent_count', '2017_rent_count', '2018_rent_count', '2019_rent_count', '2020_rent_count', '2021_rent_count']

# %%
# Use LassoCV to select features based on their coefficients for rent count prediction

# Initialize and fit the LassoCV model
lasso_count = LassoCV(cv=5, random_state=42)
lasso_count.fit(X_count_scaled, y_count)

# Get coefficients from the Lasso model
lasso_coefficients_count = pd.Series(lasso_count.coef_, index=X_count.columns)

# Select features with non-zero coefficients
selected_features_lasso_count = lasso_coefficients_count[lasso_coefficients_count != 0].index.tolist()

print("Features selected by Lasso Regression for rent count:")
print(selected_features_lasso_count)
# Out:
# Features selected by Lasso Regression for rent count:
# ['2000_rent_count', '2007_rent_count', '2007_rent_median', '2008_rent_median', '2009_rent_count', '2009_rent_median', '2015_rent_count', '2017_rent_count', '2021_rent_count', 'population_growth_rate', '2028_population', 'income_growth_rate', '2001_rent_median_growth', '2003_rent_median_growth', '2005_rent_median_growth', '2006_rent_median_growth', '2007_rent_median_growth', '2010_rent_median_growth', '2012_rent_median_growth', '2013_rent_median_growth', '2014_rent_median_growth', '2017_rent_median_growth', '2018_rent_median_growth', '2020_rent_median_growth', '2021_rent_median_growth', '2022_rent_median_growth']

# %%
# Use Random Forest Regressor to determine feature importance for rent count prediction

# Initialize and fit the Random Forest model
rf_count = RandomForestRegressor(n_estimators=100, random_state=42)
rf_count.fit(X_count, y_count)

# Get feature importances from the Random Forest model
importances_count = pd.Series(rf_count.feature_importances_, index=X_count.columns)

# Select the top 20 features based on importance
selected_features_rf_count = importances_count.sort_values(ascending=False).head(20).index.tolist()

print("Top features for rent count based on Random Forest:")
print(selected_features_rf_count)
# Out:
# Top features for rent count based on Random Forest:
# ['2021_rent_count', '2017_rent_count', '2013_rent_count', '2012_rent_count', '2010_rent_count', '2020_rent_count', '2019_rent_count', '2018_rent_count', '2008_rent_count', '2011_rent_count', '2015_rent_count', '2014_rent_count', '2016_rent_count', '2007_rent_count', '2009_rent_count', '2021_rent_median_growth', '2005_rent_count', '2004_rent_median_growth', '2004_rent_count', '2002_rent_count']

# %%
# Use RFE with Random Forest to select features for rent count prediction

# Initialize the RFE model
rfe_selector_count = RFE(estimator=RandomForestRegressor(n_estimators=100, random_state=42), n_features_to_select=20, step=1)
rfe_selector_count.fit(X_count, y_count)

# Get the selected features
selected_features_rfe_count = X_count.columns[rfe_selector_count.support_].tolist()

print("Features selected by RFE for rent count:")
print(selected_features_rfe_count)
# Out:
# Features selected by RFE for rent count:
# ['2005_rent_count', '2006_rent_count', '2007_rent_count', '2008_rent_count', '2009_rent_count', '2010_rent_count', '2011_rent_count', '2012_rent_count', '2013_rent_count', '2014_rent_count', '2015_rent_count', '2016_rent_count', '2017_rent_count', '2018_rent_count', '2019_rent_count', '2020_rent_count', '2021_rent_count', '2004_rent_median_growth', '2011_rent_median_growth', '2021_rent_median_growth']

# %%
# Combine features selected by different methods for rent count prediction

# Combine selected features into a set to avoid duplicates
selected_features_count = set(selected_features_univariate_count) | set(selected_features_lasso_count) | set(selected_features_rf_count) | set(selected_features_rfe_count)

# Convert the set back to a list
final_selected_features_count = list(selected_features_count)

print("Final selected features for rent count prediction:")
print(final_selected_features_count)
# Out:
# Final selected features for rent count prediction:
# ['2004_rent_count', '2003_rent_median_growth', '2016_rent_count', '2010_rent_count', '2010_rent_median_growth', '2007_rent_count', '2005_rent_median_growth', '2018_rent_median_growth', '2012_rent_median_growth', '2008_rent_median', '2011_rent_median_growth', '2020_rent_median_growth', '2015_rent_count', '2001_rent_median_growth', '2012_rent_count', '2020_rent_count', '2021_rent_median_growth', '2000_rent_count', '2006_rent_count', '2007_rent_median', 'population_growth_rate', '2014_rent_median_growth', '2011_rent_count', '2006_rent_median_growth', '2008_rent_count', '2013_rent_median_growth', '2002_rent_count', '2009_rent_count', '2017_rent_median_growth', '2021_rent_count', '2007_rent_median_growth', '2013_rent_count', '2014_rent_count', '2009_rent_median', '2028_population', '2005_rent_count', '2003_rent_count', '2004_rent_median_growth', '2017_rent_count', '2018_rent_count', 'income_growth_rate', '2022_rent_median_growth', '2019_rent_count']

# %%
# 8. Feature Engineering with Division by Zero Handling

import numpy as np

# Calculate rent count growth rates with zero division handling
for year in range(2001, 2023):
    current_year = f"{year}_rent_count"
    previous_year = f"{year - 1}_rent_count"
    growth_rate_col = f"{year}_rent_count_growth"
    if current_year in rent_df.columns and previous_year in rent_df.columns:
        # Replace zeros in the previous year with NaN to avoid division by zero
        denominator = rent_df[previous_year].replace(0, np.nan)
        # Calculate growth rate
        rent_df[growth_rate_col] = (rent_df[current_year] - rent_df[previous_year]) / denominator

# Handle infinities and NaNs in the growth rate features
growth_features_count = [col for col in rent_df.columns if '_rent_count_growth' in col]

# Replace infinities with NaN
rent_df[growth_features_count] = rent_df[growth_features_count].replace([np.inf, -np.inf], np.nan)

# Fill NaN values with zero or another appropriate value (e.g., mean of the column)
rent_df[growth_features_count] = rent_df[growth_features_count].fillna(0)

# Add new growth rate features to the features list
final_selected_features_count += growth_features_count
final_selected_features_count = list(set(final_selected_features_count))

# %%
rent_df
# Out:
#                                     suburb  postcode        SA2  \
# 0    Albert Park-Middle Park-West St Kilda    3004.0  206041119
# 1    Albert Park-Middle Park-West St Kilda    3004.0  206041125
# 2    Albert Park-Middle Park-West St Kilda    3004.0  206051128
# 3    Albert Park-Middle Park-West St Kilda    3004.0  206051513
# 4                                 Armadale    3143.0  206061135
# ..                                     ...       ...        ...
# 204                              Traralgon    3844.0  205051104
# 205                            Wanagaratta    3677.0  204021066
# 206                               Warragul    3820.0  205011079
# 207                            Warrnambool    3280.0  217041479
# 208                                Wodonga    3690.0  204031492
#
#                 SA2 NAME                                           geometry  \
# 0         East Melbourne  POLYGON ((144.9739585748236 -37.81330241814959...
# 1     South Yarra - West  POLYGON ((144.97455041239857 -37.8346653683224...
# 2            Albert Park  POLYGON ((144.96766973330057 -37.8373669078686...
# 3     St Kilda - Central  POLYGON ((144.9822465081365 -37.86154000901546...
# 4               Armadale  POLYGON ((145.01167433388778 -37.8535692509816...
# ..                   ...                                                ...
# 204               Yarram  MULTIPOLYGON (((146.6219024767579 -38.75020696...
# 205           Wangaratta  POLYGON ((146.26630196919123 -36.3498597306351...
# 206             Warragul  POLYGON ((145.89336672749718 -38.1442268948162...
# 207  Warrnambool - North  POLYGON ((142.4366836580644 -38.35544112113083...
# 208              Wodonga  POLYGON ((146.86854138833078 -36.1156143441792...
#
#      2000_rent_count  2000_rent_median  2001_rent_count  2001_rent_median  \
# 0             4632.0            266.25           4990.0            281.25
# 1             4632.0            266.25           4990.0            281.25
# 2             4632.0            266.25           4990.0            281.25
# 3             4632.0            266.25           4990.0            281.25
# 4             2947.0            203.75           2904.0            222.50
# ..               ...               ...              ...               ...
# 204           3312.0            123.75           3213.0            126.25
# 205           2630.0            127.50           2340.0            131.25
# 206           1500.0            133.75           1370.0            137.50
# 207           4834.0            133.75           4318.0            141.25
# 208           5802.0            147.50           5399.0            150.00
#
#      2002_rent_count  2002_rent_median  2003_rent_count  2003_rent_median  \
# 0               4097        300.000000             6844             295.0
# 1               4097        300.000000             6844             295.0
# 2               4097        300.000000             6844             295.0
# 3               4097        300.000000             6844             295.0
# 4               2330        231.000000             3729             236.0
# ..               ...               ...              ...               ...
# 204             2399        130.000000             4200             147.0
# 205             1896        135.000000             3263             141.0
# 206             1051        151.666667             1797             162.0
# 207             3213        148.333333             5731             162.0
# 208             3932        153.333333             6398             166.0
#
#      2004_rent_count  2004_rent_median  2005_rent_count  2005_rent_median  \
# 0               4963            300.00             5048            302.50
# 1               4963            300.00             5048            302.50
# 2               4963            300.00             5048            302.50
# 3               4963            300.00             5048            302.50
# 4               2839            238.75             2779            243.25
# ..               ...               ...              ...               ...
# 204             3584            159.50             3580            167.50
# 205             2414            153.25             2282            162.50
# 206             1561            173.75             1598            182.50
# 207             4654            178.75             4677            193.75
# 208             5197            181.25             5159            192.50
#
#      2006_rent_count  2006_rent_median  2007_rent_count  2007_rent_median  \
# 0               4101            317.00             3430            362.50
# 1               4101            317.00             3430            362.50
# 2               4101            317.00             3430            362.50
# 3               4101            317.00             3430            362.50
# 4               2684            261.25             2548            295.00
# ..               ...               ...              ...               ...
# 204             3720            175.00             3586            186.25
# 205             2454            172.50             2494            181.25
# 206             1654            187.50             1684            193.25
# 207             4785            203.25             4785            212.50
# 208             4841            210.00             5242            218.75
#
#      2008_rent_count  2008_rent_median  2009_rent_count  2009_rent_median  \
# 0               3609            389.50             3690            417.50
# 1               3609            389.50             3690            417.50
# 2               3609            389.50             3690            417.50
# 3               3609            389.50             3690            417.50
# 4               2560            331.25             2316            350.75
# ..               ...               ...              ...               ...
# 204             3836            206.25             3958            225.00
# 205             2511            187.50             2545            196.25
# 206             1606            202.75             1488            220.00
# 207             5108            222.50             4980            240.25
# 208             5643            227.50             5397            233.75
#
#      2010_rent_count  2010_rent_median  2011_rent_count  2011_rent_median  \
# 0               3849            431.25             3666            445.00
# 1               3849            431.25             3666            445.00
# 2               3849            431.25             3666            445.00
# 3               3849            431.25             3666            445.00
# 4               2425            363.75             2580            382.50
# ..               ...               ...              ...               ...
# 204             4176            231.25             4257            248.00
# 205             2362            206.25             2496            216.25
# 206             1454            235.00             1588            250.00
# 207             4532            262.50             5049            281.25
# 208             5414            241.25             5818            250.00
#
#      2012_rent_count  2012_rent_median  2013_rent_count  2013_rent_median  \
# 0               3892            460.00             3894            461.50
# 1               3892            460.00             3894            461.50
# 2               3892            460.00             3894            461.50
# 3               3892            460.00             3894            461.50
# 4               2422            385.00             2515            395.00
# ..               ...               ...              ...               ...
# 204             4271            250.00             4340            256.25
# 205             2583            221.25             2469            235.00
# 206             1800            259.75             1898            267.50
# 207             5702            282.50             5939            280.00
# 208             6232            261.75             6330            270.00
#
#      2014_rent_count  2014_rent_median  2015_rent_count  2015_rent_median  \
# 0               4044            472.50             3721            491.25
# 1               4044            472.50             3721            491.25
# 2               4044            472.50             3721            491.25
# 3               4044            472.50             3721            491.25
# 4               2685            393.75             2665            399.75
# ..               ...               ...              ...               ...
# 204             4353            263.75             4320            270.00
# 205             2692            247.50             2844            250.00
# 206             1919            272.75             2007            280.00
# 207             6030            280.00             5570            285.00
# 208             6248            280.00             6248            287.50
#
#      2016_rent_count  2016_rent_median  2017_rent_count  2017_rent_median  \
# 0               3823            515.00             3600            527.75
# 1               3823            515.00             3600            527.75
# 2               3823            515.00             3600            527.75
# 3               3823            515.00             3600            527.75
# 4               2645            402.50             3122            445.00
# ..               ...               ...              ...               ...
# 204             4486            270.00             4523            276.25
# 205             2954            260.00             2788            266.25
# 206             1976            293.75             2086            305.00
# 207             5638            288.75             5284            290.00
# 208             6368            290.00             6028            298.75
#
#      2018_rent_count  2018_rent_median  2019_rent_count  2019_rent_median  \
# 0               3649            562.50             3495            568.00
# 1               3649            562.50             3495            568.00
# 2               3649            562.50             3495            568.00
# 3               3649            562.50             3495            568.00
# 4               3667            487.50             3067            481.25
# ..               ...               ...              ...               ...
# 204             4416            278.75             3822            287.50
# 205             2518            274.25             2533            287.50
# 206             1896            323.75             1977            347.00
# 207             4809            300.00             4276            322.50
# 208             5819            302.50             5573            318.75
#
#      2020_rent_count  2020_rent_median  2021_rent_count  2021_rent_median  \
# 0               3342            570.00             3695            498.75
# 1               3342            570.00             3695            498.75
# 2               3342            570.00             3695            498.75
# 3               3342            570.00             3695            498.75
# 4               2977            498.75             3289            433.75
# ..               ...               ...              ...               ...
# 204             3525            307.50             3370            345.00
# 205             2587            299.50             2242            340.00
# 206             2287            360.00             2143            383.75
# 207             3934            342.50             3458            365.00
# 208             5376            330.00             4918            355.00
#
#      2022_rent_count  2022_rent_median  2001_population  2002_population  \
# 0               3435             510.0             3731             3859
# 1               3435             510.0             5317             5233
# 2               3435             510.0            12368            12595
# 3               3435             510.0             8558             8675
# 4               3348             447.5             8632             8683
# ..               ...               ...              ...              ...
# 204             3568             375.0             5686             5626
# 205             2149             377.5            17109            17123
# 206             2072             412.5            14203            14327
# 207             3427             410.0            17053            17449
# 208             4942             395.0            15053            14994
#
#      2003_population  2004_population  2005_population  2006_population  \
# 0               4243             4460             4495             4555
# 1               5176             5183             5289             5538
# 2              12800            12997            13269            13550
# 3               8836             8965             9145             9340
# 4               8724             8770             8783             8863
# ..               ...              ...              ...              ...
# 204             5560             5491             5465             5449
# 205            17136            17175            17223            17320
# 206            14501            14654            14959            15275
# 207            17726            17937            18172            18528
# 208            14902            14762            14588            14426
#
#      2007_population  2008_population  2009_population  2010_population  \
# 0               4806             5055             5202             5272
# 1               5837             6118             6380             6418
# 2              13731            13928            14245            14595
# 3               9650             9924            10268            10494
# 4               8990             9148             9260             9318
# ..               ...              ...              ...              ...
# 204             5453             5443             5451             5419
# 205            17419            17541            17676            17837
# 206            15561            15902            16225            16632
# 207            18877            19107            19369            19634
# 208            14373            14384            14456            14616
#
#      2011_population  2012_population  2013_population  2014_population  \
# 0               5238             5280             5333             5374
# 1               6426             6400             6393             6397
# 2              15009            15142            15282            15592
# 3              10751            11323            11798            12234
# 4               9301             9308             9338             9387
# ..               ...              ...              ...              ...
# 204             5329             5335             5345             5349
# 205            17980            18144            18294            18437
# 206            16964            17284            17635            18004
# 207            19879            20253            20612            20930
# 208            14743            14863            15018            15169
#
#      2015_population  2016_population  2017_population  2018_population  \
# 0               5411             5475             5496             5412
# 1               6405             6453             6833             6957
# 2              16053            16490            16500            16728
# 3              12561            13014            13315            13589
# 4               9485             9619             9635             9906
# ..               ...              ...              ...              ...
# 204             5351             5371             5403             5437
# 205            18624            18940            19193            19471
# 206            18466            19088            19766            20501
# 207            21217            21442            21688            21954
# 208            15368            15615            15566            15547
#
#      2019_population  2020_population  2021_population  2022_population  \
# 0               5416             5383             4959             4889
# 1               7055             6960             6536             6573
# 2              17081            16955            16011            16177
# 3              13676            13380            12086            12256
# 4              10044            10075             9433             9376
# ..               ...              ...              ...              ...
# 204             5474             5545             5555             5588
# 205            19624            19716            19884            19969
# 206            21283            22099            23098            23787
# 207            22184            22416            22470            22586
# 208            15408            15256            15053            14880
#
#      2023_population  population_growth_rate  2024_population  \
# 0               5100                0.014868      5175.824488
# 1               6789                0.011538      6867.332701
# 2              16861                0.014356     17103.056186
# 3              13186                0.020345     13454.264995
# 4               9769                0.005810      9825.761894
# ..               ...                     ...              ...
# 204             5580               -0.000830      5575.367063
# 205            19969                0.007060     20109.982091
# 206            24417                0.024978     25026.880649
# 207            22762                0.013223     23062.981165
# 208            14814               -0.000685     14803.850572
#
#      2025_population  2026_population  2027_population  2028_population  \
# 0        5252.776301      5330.872198      5410.129189      5490.564538
# 1        6946.569219      7026.719983      7107.795540      7189.806561
# 2       17348.587326     17597.643306     17850.274728     18106.532923
# 3       13727.987756     14007.279320     14292.252982     14583.024344
# 4        9882.853598      9940.277028      9998.034111     10056.126787
# ..               ...              ...              ...              ...
# 204      5570.737973      5566.112726      5561.491320      5556.873751
# 205     20251.959521     20394.939320     20538.928562     20683.934375
# 206     25651.994718     26292.722702     26949.454601     27622.590157
# 207     23367.942194     23676.935712     23990.015041     24307.234208
# 208     14793.708098     14783.572572     14773.443991     14763.322349
#
#      2016_income  2017_income  2018_income  2019_income  2020_income  \
# 0        69469.0      71759.0      75755.0      77804.0      81648.0
# 1        64865.0      68512.0      70451.0      69578.0      72567.0
# 2        65352.0      66627.0      67518.0      68933.0      73107.0
# 3        53464.0      56940.0      59644.0      60523.0      64644.0
# 4        63296.0      66098.0      69563.0      72012.0      73321.0
# ..           ...          ...          ...          ...          ...
# 204      35097.0      38003.0      37232.0      38845.0      41677.0
# 205      43782.0      45587.0      47525.0      48372.0      51216.0
# 206      43110.0      45069.0      47709.0      49466.0      51745.0
# 207      44509.0      46945.0      48855.0      50654.0      52518.0
# 208      44888.0      45351.0      48035.0      49329.0      51193.0
#
#      average_income  income_growth_rate  affluence_index  \
# 0           75287.0            0.175316     52700.952595
# 1           69194.6            0.118739     48436.255622
# 2           68307.4            0.118665     47815.215600
# 3           59043.0            0.209113     41330.162734
# 4           68858.0            0.158383     48200.647515
# ..              ...                 ...              ...
# 204         38170.8            0.187480     26719.616244
# 205         47296.4            0.169796     33107.530939
# 206         47419.8            0.200302     33193.920090
# 207         48696.2            0.179941     34087.393982
# 208         47759.2            0.140461     33431.482138
#
#                                               geometry  \
# 0    POLYGON ((144.9739585748236 -37.81330241814959...
# 1    POLYGON ((144.97455041239857 -37.8346653683224...
# 2    POLYGON ((144.96766973330057 -37.8373669078686...
# 3    POLYGON ((144.9822465081365 -37.86154000901546...
# 4    POLYGON ((145.01167433388778 -37.8535692509816...
# ..                                                 ...
# 204  MULTIPOLYGON (((146.6219024767579 -38.75020696...
# 205  POLYGON ((146.26630196919123 -36.3498597306351...
# 206  POLYGON ((145.89336672749718 -38.1442268948162...
# 207  POLYGON ((142.4366836580644 -38.35544112113083...
# 208  POLYGON ((146.86854138833078 -36.1156143441792...
#
#      2001_rent_median_growth  2002_rent_median_growth  \
# 0                   0.056338                 0.066667
# 1                   0.056338                 0.066667
# 2                   0.056338                 0.066667
# 3                   0.056338                 0.066667
# 4                   0.092025                 0.038202
# ..                       ...                      ...
# 204                 0.020202                 0.029703
# 205                 0.029412                 0.028571
# 206                 0.028037                 0.103030
# 207                 0.056075                 0.050147
# 208                 0.016949                 0.022222
#
#      2003_rent_median_growth  2004_rent_median_growth  \
# 0                  -0.016667                 0.016949
# 1                  -0.016667                 0.016949
# 2                  -0.016667                 0.016949
# 3                  -0.016667                 0.016949
# 4                   0.021645                 0.011653
# ..                       ...                      ...
# 204                 0.130769                 0.085034
# 205                 0.044444                 0.086879
# 206                 0.068132                 0.072531
# 207                 0.092135                 0.103395
# 208                 0.082609                 0.091867
#
#      2005_rent_median_growth  2006_rent_median_growth  \
# 0                   0.008333                 0.047934
# 1                   0.008333                 0.047934
# 2                   0.008333                 0.047934
# 3                   0.008333                 0.047934
# 4                   0.018848                 0.073998
# ..                       ...                      ...
# 204                 0.050157                 0.044776
# 205                 0.060359                 0.061538
# 206                 0.050360                 0.027397
# 207                 0.083916                 0.049032
# 208                 0.062069                 0.090909
#
#      2007_rent_median_growth  2008_rent_median_growth  \
# 0                   0.143533                 0.074483
# 1                   0.143533                 0.074483
# 2                   0.143533                 0.074483
# 3                   0.143533                 0.074483
# 4                   0.129187                 0.122881
# ..                       ...                      ...
# 204                 0.064286                 0.107383
# 205                 0.050725                 0.034483
# 206                 0.030667                 0.049159
# 207                 0.045510                 0.047059
# 208                 0.041667                 0.040000
#
#      2009_rent_median_growth  2010_rent_median_growth  \
# 0                   0.071887                 0.032934
# 1                   0.071887                 0.032934
# 2                   0.071887                 0.032934
# 3                   0.071887                 0.032934
# 4                   0.058868                 0.037063
# ..                       ...                      ...
# 204                 0.090909                 0.027778
# 205                 0.046667                 0.050955
# 206                 0.085080                 0.068182
# 207                 0.079775                 0.092612
# 208                 0.027473                 0.032086
#
#      2011_rent_median_growth  2012_rent_median_growth  \
# 0                   0.031884                 0.033708
# 1                   0.031884                 0.033708
# 2                   0.031884                 0.033708
# 3                   0.031884                 0.033708
# 4                   0.051546                 0.006536
# ..                       ...                      ...
# 204                 0.072432                 0.008065
# 205                 0.048485                 0.023121
# 206                 0.063830                 0.039000
# 207                 0.071429                 0.004444
# 208                 0.036269                 0.047000
#
#      2013_rent_median_growth  2014_rent_median_growth  \
# 0                   0.003261                 0.023835
# 1                   0.003261                 0.023835
# 2                   0.003261                 0.023835
# 3                   0.003261                 0.023835
# 4                   0.025974                -0.003165
# ..                       ...                      ...
# 204                 0.025000                 0.029268
# 205                 0.062147                 0.053191
# 206                 0.029836                 0.019626
# 207                -0.008850                 0.000000
# 208                 0.031519                 0.037037
#
#      2015_rent_median_growth  2016_rent_median_growth  \
# 0                   0.039683                 0.048346
# 1                   0.039683                 0.048346
# 2                   0.039683                 0.048346
# 3                   0.039683                 0.048346
# 4                   0.015238                 0.006879
# ..                       ...                      ...
# 204                 0.023697                 0.000000
# 205                 0.010101                 0.040000
# 206                 0.026581                 0.049107
# 207                 0.017857                 0.013158
# 208                 0.026786                 0.008696
#
#      2017_rent_median_growth  2018_rent_median_growth  \
# 0                   0.024757                 0.065846
# 1                   0.024757                 0.065846
# 2                   0.024757                 0.065846
# 3                   0.024757                 0.065846
# 4                   0.105590                 0.095506
# ..                       ...                      ...
# 204                 0.023148                 0.009050
# 205                 0.024038                 0.030047
# 206                 0.038298                 0.061475
# 207                 0.004329                 0.034483
# 208                 0.030172                 0.012552
#
#      2019_rent_median_growth  2020_rent_median_growth  \
# 0                   0.009778                 0.003521
# 1                   0.009778                 0.003521
# 2                   0.009778                 0.003521
# 3                   0.009778                 0.003521
# 4                  -0.012821                 0.036364
# ..                       ...                      ...
# 204                 0.031390                 0.069565
# 205                 0.048314                 0.041739
# 206                 0.071815                 0.037464
# 207                 0.075000                 0.062016
# 208                 0.053719                 0.035294
#
#      2021_rent_median_growth  2022_rent_median_growth  2001_rent_count_growth  \
# 0                  -0.125000                 0.022556                0.077288
# 1                  -0.125000                 0.022556                0.077288
# 2                  -0.125000                 0.022556                0.077288
# 3                  -0.125000                 0.022556                0.077288
# 4                  -0.130326                 0.031700               -0.014591
# ..                       ...                      ...                     ...
# 204                 0.121951                 0.086957               -0.029891
# 205                 0.135225                 0.110294               -0.110266
# 206                 0.065972                 0.074919               -0.086667
# 207                 0.065693                 0.123288               -0.106744
# 208                 0.075758                 0.112676               -0.069459
#
#      2002_rent_count_growth  2003_rent_count_growth  2004_rent_count_growth  \
# 0                 -0.178958                0.670491               -0.274839
# 1                 -0.178958                0.670491               -0.274839
# 2                 -0.178958                0.670491               -0.274839
# 3                 -0.178958                0.670491               -0.274839
# 4                 -0.197658                0.600429               -0.238670
# ..                      ...                     ...                     ...
# 204               -0.253346                0.750729               -0.146667
# 205               -0.189744                0.720992               -0.260190
# 206               -0.232847                0.709800               -0.131330
# 207               -0.255906                0.783691               -0.187925
# 208               -0.271717                0.627162               -0.187715
#
#      2005_rent_count_growth  2006_rent_count_growth  2007_rent_count_growth  \
# 0                  0.017127               -0.187599               -0.163619
# 1                  0.017127               -0.187599               -0.163619
# 2                  0.017127               -0.187599               -0.163619
# 3                  0.017127               -0.187599               -0.163619
# 4                 -0.021134               -0.034185               -0.050671
# ..                      ...                     ...                     ...
# 204               -0.001116                0.039106               -0.036022
# 205               -0.054681                0.075372                0.016300
# 206                0.023703                0.035044                0.018138
# 207                0.004942                0.023092                0.000000
# 208               -0.007312               -0.061640                0.082834
#
#      2008_rent_count_growth  2009_rent_count_growth  2010_rent_count_growth  \
# 0                  0.052187                0.022444                0.043089
# 1                  0.052187                0.022444                0.043089
# 2                  0.052187                0.022444                0.043089
# 3                  0.052187                0.022444                0.043089
# 4                  0.004710               -0.095312                0.047064
# ..                      ...                     ...                     ...
# 204                0.069716                0.031804                0.055078
# 205                0.006816                0.013540               -0.071906
# 206               -0.046318               -0.073474               -0.022849
# 207                0.067503               -0.025059               -0.089960
# 208                0.076498               -0.043594                0.003150
#
#      2011_rent_count_growth  2012_rent_count_growth  2013_rent_count_growth  \
# 0                 -0.047545                0.061648                0.000514
# 1                 -0.047545                0.061648                0.000514
# 2                 -0.047545                0.061648                0.000514
# 3                 -0.047545                0.061648                0.000514
# 4                  0.063918               -0.061240                0.038398
# ..                      ...                     ...                     ...
# 204                0.019397                0.003289                0.016155
# 205                0.056732                0.034856               -0.044135
# 206                0.092160                0.133501                0.054444
# 207                0.114078                0.129333                0.041564
# 208                0.074621                0.071158                0.015725
#
#      2014_rent_count_growth  2015_rent_count_growth  2016_rent_count_growth  \
# 0                  0.038521               -0.079871                0.027412
# 1                  0.038521               -0.079871                0.027412
# 2                  0.038521               -0.079871                0.027412
# 3                  0.038521               -0.079871                0.027412
# 4                  0.067594               -0.007449               -0.007505
# ..                      ...                     ...                     ...
# 204                0.002995               -0.007581                0.038426
# 205                0.090320                0.056464                0.038678
# 206                0.011064                0.045857               -0.015446
# 207                0.015322               -0.076285                0.012208
# 208               -0.012954                0.000000                0.019206
#
#      2017_rent_count_growth  2018_rent_count_growth  2019_rent_count_growth  \
# 0                 -0.058331                0.013611               -0.042203
# 1                 -0.058331                0.013611               -0.042203
# 2                 -0.058331                0.013611               -0.042203
# 3                 -0.058331                0.013611               -0.042203
# 4                  0.180340                0.174568               -0.163621
# ..                      ...                     ...                     ...
# 204                0.008248               -0.023657               -0.134511
# 205               -0.056195               -0.096844                0.005957
# 206                0.055668               -0.091083                0.042722
# 207               -0.062788               -0.089894               -0.110834
# 208               -0.053392               -0.034672               -0.042275
#
#      2020_rent_count_growth  2021_rent_count_growth  2022_rent_count_growth
# 0                 -0.043777                0.105625               -0.070365
# 1                 -0.043777                0.105625               -0.070365
# 2                 -0.043777                0.105625               -0.070365
# 3                 -0.043777                0.105625               -0.070365
# 4                 -0.029345                0.104803                0.017939
# ..                      ...                     ...                     ...
# 204               -0.077708               -0.043972                0.058754
# 205                0.021319               -0.133359               -0.041481
# 206                0.156803               -0.062965               -0.033131
# 207               -0.079981               -0.120996               -0.008965
# 208               -0.035349               -0.085193                0.004880
#
# [209 rows x 133 columns]

# %%
# 9. Prepare Data for Modeling with Data Cleaning

# Extract the selected features and target variable
X_final_count = rent_df[final_selected_features_count]
y_final_count = rent_df[target_rent_count]

# Handle infinite values and NaNs in features
X_final_count = X_final_count.replace([np.inf, -np.inf], np.nan)
X_final_count = X_final_count.fillna(0)  # Or use appropriate imputation

# Ensure all feature values are finite numbers
if not np.all(np.isfinite(X_final_count.values)):
    print("Warning: X contains infinite or NaN values even after preprocessing.")

# Convert data types to float64 for higher precision
X_final_count = X_final_count.astype(np.float64)
y_final_count = y_final_count.astype(np.float64)

# Handle missing values in the target variable
y_final_count = y_final_count.fillna(y_final_count.mean())

# %% [markdown]
# Model evaluation

# %%
# Model for Rent Median Prediction

# Split the data into training and testing sets
X_train_median, X_test_median, y_train_median, y_test_median = train_test_split(X_final_median, y_final_median, test_size=0.2, random_state=42)

# Initialize and train the Random Forest model
model_median = RandomForestRegressor(n_estimators=100, random_state=42)
model_median.fit(X_train_median, y_train_median)

# Predict on the test set
y_pred_median = model_median.predict(X_test_median)

# Evaluate the model performance
print("Model Performance for Rent Median Prediction:")
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test_median, y_pred_median))
print("Mean Squared Error (MSE):", mean_squared_error(y_test_median, y_pred_median))
print("Root Mean Squared Error (RMSE):", np.sqrt(mean_squared_error(y_test_median, y_pred_median)))
print("R^2 Score:", r2_score(y_test_median, y_pred_median))
# Out:
# Model Performance for Rent Median Prediction:
# Mean Absolute Error (MAE): 7.238630952380949
# Mean Squared Error (MSE): 117.37851711309524
# Root Mean Squared Error (RMSE): 10.834136657486615
# R^2 Score: 0.963318914890723

# %%
# Model for Rent Count Prediction

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Split the data into training and testing sets
X_train_count, X_test_count, y_train_count, y_test_count = train_test_split(X_final_count, y_final_count, test_size=0.2, random_state=42)

# Initialize and train the Random Forest model
model_count = RandomForestRegressor(n_estimators=100, random_state=42)
model_count.fit(X_train_count, y_train_count)

# Predict on the test set
y_pred_count = model_count.predict(X_test_count)

# Evaluate the model performance
print("Model Performance for Rent Count Prediction:")
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test_count, y_pred_count))
print("Mean Squared Error (MSE):", mean_squared_error(y_test_count, y_pred_count))
print("Root Mean Squared Error (RMSE):", np.sqrt(mean_squared_error(y_test_count, y_pred_count)))
print("R^2 Score:", r2_score(y_test_count, y_pred_count))
# Out:
# Model Performance for Rent Count Prediction:
# Mean Absolute Error (MAE): 311.59785714285726
# Mean Squared Error (MSE): 307095.92115000065
# Root Mean Squared Error (RMSE): 554.1623599181025
# R^2 Score: 0.997221690268482

# %% [markdown]
# Save the training data

# %%
# Prepare  data for rent median model
X_final_median = rent_df[final_selected_features_median]
y_final_median = rent_df[target_rent_median]

# Handle missing values
X_final_median = X_final_median.fillna(0)
y_final_median = y_final_median.fillna(y_final_median.mean())

# Split the data into training and testing sets
X_train_median, X_test_median, y_train_median, y_test_median = train_test_split(X_final_median, y_final_median, test_size=0.2, random_state=42)

# Combine X_train and y_train into a single DataFrame
train_data_median = X_train_median.copy()
train_data_median['target_rent_median'] = y_train_median

# Save the training data to a CSV file
model_median_data_path = str(Path.cwd().parent/'data'/'curated'/'rent_median_training_data.csv')
#train_data_median.to_csv(model_median_data_path, index=False)

#print(f"Training data for rent median prediction saved to {model_median_data_path}")

# %%
# Prepare data for rent count model
X_final_count = rent_df[final_selected_features_count]
y_final_count = rent_df[target_rent_count]

# Handle missing values
X_final_count = X_final_count.fillna(0)
y_final_count = y_final_count.fillna(y_final_count.mean())

# Split the data into training and testing sets
X_train_count, X_test_count, y_train_count, y_test_count = train_test_split(X_final_count, y_final_count, test_size=0.2, random_state=42)

# Combine X_train and y_train into a single DataFrame
train_data_count = X_train_count.copy()
train_data_count['target_rent_count'] = y_train_count

# Save the training data to a CSV file
#model_count_data_path= str(Path.cwd().parent/'data'/'curated'/'rent_count_training_data.csv')
#train_data_count.to_csv(model_count_data_path, index=False)

#print(f"Training data for rent count prediction saved to {model_count_data_path}")
